# %% [markdown]
# <a href="https://colab.research.google.com/github/mig-angel-delgado/UEES-IA-S1-DelgadoMiguel/blob/main/Notebooks/Ejemplo_02_Visualizacion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MADM - gráficos con Matplotlib, Seaborn y Plotly.

import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')

sns.countplot(data=titanic, x='sex', hue='survived')
plt.title("Supervivencia por sexo")
plt.show()

# %%
import plotly.express as px

fig = px.scatter(
    iris,
    x="sepal_length",
    y="sepal_width",
    color="species",
    title="Iris con Plotly"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2509051710.py in <cell line: 0>()
#       2
#       3 fig = px.scatter(
# ----> 4     iris,
#       5     x="sepal_length",
#       6     y="sepal_width",
#
# NameError: name 'iris' is not defined
